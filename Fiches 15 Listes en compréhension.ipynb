# %% [markdown]
# # Tableaux

# %% [markdown]
# ## Exemple 2

# %%
from random import randint

def renvoie_ligne(M,l):
    if n>len(M):
        return'Erreur de ligne.'
    else:
        return M[l-1]

def renvoie_colonne(M,c):
    if c>len(M[0]):
        return'Erreur de colonne.'
    else:
        return[el[n-1] for el in M]

M=[[randint(0,1) for a in range(5)] for b in range(3)]

# %%
def affichage_humain(M):
    ch=''
    for el in M:
        ch=ch+str(el)+'\n'
    return ch
