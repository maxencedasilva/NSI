# %% [markdown]
# # Exercice 4

# %%
from random import randint

def dicho(x,L):
    g=0
    d=len(L)-1
    trouv=0
    while trouv==0 and g<=d:
        m=(g+d)//2
        if L[m]==x:
            trouv=1
        elif L[m]<x:
            g=m+1
        else:
            d=m-1
    if trouv==0:
        print('Cible non trouvée.')
    else:
        print("Cible trouvée à l'indice %s." %(m))

L=[randint(1,10) for _ in range(10)]
L.sort()
x=int(input('Donner la cible : '))
print(L)
dicho(x,L)
# Out:
# Donner la cible : 5
# [1, 1, 2, 3, 5, 7, 7, 10, 10, 10]
# Cible trouvée à l'indice 4.

# %% [markdown]
# # Exercice 5

# %%
liste_amis=['Anna','Ben','Max','Hector','Zoé','Karine','Ursula','Andréa','Claire','Sarah','Jim','Xavier','Elie','Arthur',
            'Alice','Bob','Olga','Mathéo','Rachelle']

def dicho(x,L):
    g=0
    d=len(L)-1
    trouv=0
    while trouv==0 and g<=d:
        m=(g+d)//2
        if L[m]==x:
            trouv=1
        elif L[m]<x:
            g=m+1
        else:
            d=m-1
    if trouv==0:
        print('Cible non trouvée.')
    else:
        print("Cible trouvée à l'indice %s." %(m))
        
nom=input("Choisir un nom dans la liste d'amis : ")
liste_amis.sort()
print(liste_amis)
dicho(nom,liste_amis)
# Out:
# Choisir un nom dans la liste d'amis : MAx
# ['Alice', 'Andréa', 'Anna', 'Arthur', 'Ben', 'Bob', 'Claire', 'Elie', 'Hector', 'Jim', 'Karine', 'Mathéo', 'Max', 'Olga', 'Rachelle', 'Sarah', 'Ursula', 'Xavier', 'Zoé']
# Cible non trouvée.
