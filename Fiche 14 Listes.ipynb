# %% [markdown]
# ## Exemple 1

# %%
L=['Ferrari','McLaren','Williams','Mercedes','Redbull','AlphaTauri','AlfaRomeo','Haas']
for element in L:
    if len(element)<=7:
        print(element)

# %% [markdown]
# ## Exemple 7

# %%
def extrema(l):
    min=max=l[0]
    for i in range(len(l)):
        if l[i]<min:
            min=l[i]
        elif l[i]>max:
    return min, max

def somme(l):
    somme=0
    for i in range(len(l)):
        somme=somme+l[i]
    return somme

def moyenne(l):
    if len(l)==0:
        return 'Erreur, liste vide.'
    else:
        return somme(l)/len(l)

def appart_pos(l,n):
    for i in range(len(l)):
        if l[i]==n:
            return 'n appartient à la liste et son premier rang est',i
            break
        elif i==len(l)-1:
            return "n'appartient pas à la liste."
