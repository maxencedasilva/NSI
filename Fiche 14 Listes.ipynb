# %% [markdown]
# ## Exemple 1

# %%
L=['Ferrari','McLaren','Williams','Mercedes','Redbull','AlphaTauri','AlfaRomeo','Haas']
for element in L:
    if len(element)<=7:
        print(element)

# %% [markdown]
# ## Exemple 2
